# %%
import chess
import random
import time
from IPython.display import display

# Welcomes the user and prompts a gamemode choice
def welcome():
    display('Welcome to the world of chess puzzles! You will be playing as white in all the puzzles and trying to checkmate the computer. Type UCI notation to move (the square with the piece you want to move followed by the square you want to move to ex.e2e4).')
    time.sleep(1.5)
    display('Would you like to play Survival Mode or Time Trial? Type [Survival] OR [Time] OR [Endless] OR [Custom]')
    global gameChoice
    gameChoice = input().lower()

# Chooses random puzzle from list
def choosePuzzle():
# Database of checkmate in 2 puzzles in FEN notation
    puzzleDatabase = ['r1bq1rkb/ppp2n1p/5n2/4p1NN/5pQ1/1BP5/PP3PPP/R1B1K2R w KQ - 1 0','2r5/3nbkp1/2q1p1p1/1p1n2P1/3P4/2p1P1NQ/1P1B1P2/1B4KR w - - 1 0','3q2r1/p2b1k2/1pnBp1N1/3p1pQP/6P1/5R2/2r2P2/4RK2 w - - 1 0','rq3rk1/3n1pp1/pb4n1/3N2P1/1pB1QP2/4B3/PP6/2KR3R w - - 1 0','3rk2r/p1qn1pp1/1p2pb1p/7P/2Pp4/B1P1QP2/P1B1KP2/3R3R w k - 1 0','8/p1R3p1/4p1kn/3p3N/3Pr2P/6P1/PP3K2/8 w - - 1 0','r3nr1k/1b2Nppp/pn6/q3p1P1/P1p4Q/R7/1P2PP1P/2B2RK1 w - - 1 0','5b2/q4r1p/p3k1p1/2pNppP1/1P6/3Q1P1P/P7/1K1R4 w - - 1 0','6k1/5p2/p3bRpQ/4q3/2r3P1/6NP/P1p2R1K/1r6 w - - 1 0','3R1rk1/1pp2pp1/1p6/8/8/P7/1q4BP/3Q2K1 w - - 1 0','2Q5/pp2rk1p/3p2pq/2bP1r2/5RR1/1P2P3/PB3P1P/7K w - - 1 0','q2br1k1/1b4pp/3Bp3/p6n/1p3R2/3B1N2/PP2QPPP/6K1 w - - 1 0','3rrk2/2p2pR1/p4n2/1p1PpP2/2p2q1P/3P1BQ1/PPP5/6RK w - - 1 0','r2r3k/b1qn2pp/1p2Bp2/2p2P2/PP1pQ3/7R/1B3PPP/5RK1 w - - 1 0','3r2k1/p1p2p2/bp2p1nQ/4PB1P/2pr3q/6R1/PP3PP1/3R2K1 w - - 1 0','2QR4/6b1/1p4pk/7p/5n1P/4rq2/5P2/5BK1 w - - 1 0','6rk/6pp/5p2/p7/P2Q1N2/4P1P1/2r2n1P/6K1 w - - 1 0','r4kr1/pbNn1q1p/1p6/2p2BPQ/5B2/8/P6P/b4RK1 w - - 1 0','4rr2/1p5R/3p1p2/p2Bp3/P2bPkP1/1P5R/1P2K3/8 w - - 1 0','r3rknQ/1p1R1pb1/p3pqBB/2p5/8/6P1/PPP2P1P/4R1K1 w - - 1 0','r3n1rk/q3NQ1p/p2pbP2/1p4p1/1P1pP1P1/3R4/P1P4P/3B2K1 w - - 1 0','4r3/p2r1p1k/3q1Bpp/4P3/1PppR3/P5P1/5P1P/2Q3K1 w - - 1 0','r2qr2k/pp1b3p/2nQ4/2pB1p1P/3n1PpR/2NP2P1/PPP5/2K1R1N1 w - - 1 0','r2Rnk1r/1p2q1b1/7p/6pQ/4Ppb1/1BP5/PP3BPP/2K4R w - - 1 0','1r3k2/2n1p1b1/3p2QR/p1pq1pN1/bp6/7P/2P2PP1/4RBK1 w - - 1 0','r1b2rk1/ppppbpp1/7p/4R3/6Qq/2BB4/PPP2PPP/R5K1 w - - 1 0','r5rk/pp1np1bn/2pp2q1/3P1bN1/2P1N2Q/1P6/PB2PPBP/3R1RK1 w - - 1 0','4r3/2q1rpk1/p3bN1p/2p3p1/4QP2/2N4P/PP4P1/5RK1 w - - 1 0','1r2q3/1R6/3p1kp1/1ppBp1b1/p3Pp2/2PP4/PP3P2/5K1Q w - - 1 0','r4r1k/2qb3p/p2p1p2/1pnPN3/2p1Pn2/2P1N3/PPB1QPR1/6RK w - - 1 0','r1bqk2r/bppp1ppp/8/PB2N3/3n4/B7/2PPQnPP/RN2K2R w KQkq - 1 0','1q5r/1b1r1p1k/2p1pPpb/p1Pp4/3B1P1Q/1P4P1/P4KB1/2RR4 w - - 1 0','4r3/pbpn2n1/1p1prp1k/8/2PP2PB/P5N1/2B2R1P/R5K1 w - - 1 0','r1bq3r/ppp1b1kp/2n3p1/3B3Q/3p4/8/PPP2PPP/RNB2RK1 w - - 1 0','3q2r1/4n2k/p1p1rBpp/PpPpPp2/1P3P1Q/2P3R1/7P/1R5K w - - 1 0', '5K1k/7p/8/2p5/2rp4/8/p7/1B4B1 w - - 0 1', 'kn1R4/ppp5/2q5/8/8/8/8/3RK3 w - - 0 1', '5K1k/6pp/7R/8/8/8/8/6R1 w - - 0 1', '6k1/8/6K1/8/8/3r4/4r3/5R1R w - - 0 1', '8/1r6/8/3R4/k7/p1K5/4r3/R7 w - - 0 1', '4r1rk/5K1b/7R/R7/8/8/8/8 w - - 0 1', 'r1b2k1r/ppp1bppp/8/1B1Q4/5q2/2P5/PPP2PPP/R3R1K1 w - - 1 0']
    global puzzle
    puzzle = random.choice(puzzleDatabase)

# Displays puzzle
def setBoard():
    global board
    board = chess.Board(puzzle)
    display(board)

# Allows player to input move and makes the move
def playerMove():
    display('What move would you like to make?')
    global move
    move = input()
    # Legality check, will not accept moves that are not allowed and will re-prompt the user
    try:
        board.push_uci(move)
        display(board)
    except:
        display('That is not a legal move, please try another move.')
        playerMove()

# Generates the computer's move
def computerGenerate(board):
    computerChoice = list(board.legal_moves)[0]
    return computerChoice.uci()

# Makes the computer's move on the board
def computerMove(board):
    time.sleep(1)
    moveComputer = computerGenerate(board)
    board.push_uci(moveComputer)
    display(board)

# Checks if a new high score is acheived and congragulates if there is a new high score
def highScoreCheck():
    global highScore
    if score > highScore:
        highScore = score
        display(f'Congratulations!! You acheived a new high score of {highScore}!')

# Function to run survival mode
def survivalMode():
    # Choose difficulty and set lives and score
    difficulty = ''
    lives = 0
    global score
    score = 0
    playAgain = 'no'

    # Custom mode for survival, allows user to set number of lives
    if customize == 'yes':
        display('How many lives would you like?')
        lives = int(input())

# Choose difficulty and lives
    display('Welcome to surival mode, solve as many puzzles as you can to set a new high score! Be careful not to run out of lives...')
    time.sleep(2)
    if customize == 'no':
        display('Would you like to play on easy or hard mode? (3 lives or 1 life) Type [Easy] OR [Hard]')
        difficulty = input().lower()
    if difficulty == 'easy':
        lives = 3
    if difficulty == 'hard':
        lives = 1
    display(f'Your high score is: {highScore}. Good luck!')

    # Gameplay, uses other functions for simplicity
    while lives > 0:
        display('Generating new puzzle...')
        time.sleep(1) 
        choosePuzzle()
        setBoard()
        playerMove()
        display('Thinking...')
        computerGenerate(board)
        time.sleep(.5)
        computerMove(board)
        playerMove()
        time.sleep(1)
        # Scoring
        if board.is_checkmate():
            display('Checkmate, correct moves!')
            score = score + 1
            display(f'Score: {score} Lives: {lives}')
        else:
            display('Incorrect, better luck next time!')
            lives = lives - 1
            display(f'Score: {score} Lives: {lives}')
    else: # Once all lives are out, prompts to play again or try a different game and gives score
        display(f'You lose! Your score was: {score}')
        highScoreCheck()
        display('Would you like to play again or try a different game? Type [Yes] OR [Different] OR [No]')
        playAgain = input()
        if playAgain == 'yes':
            survivalMode()
        if playAgain == 'different':
            welcome()
        else:
            display('Thank you for playing!')

# Main function for time trial
def timeTrial():
    global score
    score = 0
    solveTime = 0
    timeLeft = 60
    # Custom mode, allows user to set their own time limit
    if customize == 'yes':
        display('What would you like your custom time to be in seconds?')
        timeLeft = int(input())

# Rules for the game
    display(f'Welcome to Time Trial, you will have {timeLeft} seconds to solve as many puzzles as possible.')
    time.sleep(1.5)
    display('You will be able to finish the puzzle you are working on when the time runs out.')
    time.sleep(1.5)
    display(f'Your high score is: {highScore}. Good luck!')
    time.sleep(1.5)

# Gameplay
    while timeLeft > 0:
        display('Generating new puzzle...')
        start = time.time() 
        time.sleep(.3) 
        choosePuzzle()
        setBoard()
        playerMove()
        display('Thinking...')
        computerGenerate(board)
        time.sleep(.3)
        computerMove(board)
        playerMove()
        time.sleep(1)

        # Scoring
        if board.is_checkmate():
            display('Checkmate, correct moves!')
            score = score + 1
            display(f'Score: {score}')
            end = time.time()
            solveTime = end - start
            timeLeft = timeLeft - solveTime
            display(f'{timeLeft} seconds left!')
        else: 
            display('Incorrect, better luck next time!')
            display(f'Score: {score}')
            end = time.time()
            solveTime = end - start
            timeLeft = timeLeft - solveTime
            if timeLeft < 0:
                timeLeft = 0
            display(f'{timeLeft} seconds left!')

    else: # End of game, gives score and option to play a new one
        display(f'Times up! Your score was: {score}')
        highScoreCheck()
        display('Would you like to play again or try a different game? Type [Yes] OR [Different] OR [No]')
        playAgain = input()
        if playAgain == 'yes':
            timeTrial()
        if playAgain == 'different':
            welcome()
        else:
            display('Thank you for playing!')

# Main function for endless mode, unlimited puzzles
def endless():
    global score
    score = 0

    display('Welcome to endless mode! Sovle an endless barrage of puzzles!')
    display(f'Your high score is: {highScore}. Good luck!')
    time.sleep(1)

    while True:
        display('Generating new puzzle...')
        time.sleep(1) 
        choosePuzzle()
        setBoard()
        playerMove()
        display('Thinking...')
        computerGenerate(board)
        time.sleep(.5)
        computerMove(board)
        playerMove()
        time.sleep(1)
        if board.is_checkmate():
            display('Checkmate, correct moves!')
            score = score + 1
            display(f'Score: {score}')
        else:
            display('Incorrect, better luck next time!')
            display(f'Score: {score}')    
    

# Main code to run through the whole game, first chooses which game mode to play
welcome()

# Sets high score
global highScore
highScore = 0
global customize
customize = 'no'

#Survival mode
if gameChoice == 'survival':
    survivalMode()

# Time trial mode
if gameChoice == 'time':
    timeTrial()

# Endless mode
if gameChoice == 'endless':
    endless()

# Custom mode, allows user to change lives or time limit in respective mode
if gameChoice == 'custom':
    display('In custom mode, you can change the amount of lives in survival mode or the timer in time trial mode. Which would you like to change? Type [Survival] or [Time]')
    customChoice = input().lower()
    customize = 'yes'
    if customChoice == 'survival':
        survivalMode()
    if customChoice == 'time':
        timeTrial()
